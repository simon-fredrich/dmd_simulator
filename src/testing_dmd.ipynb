# %%
import matplotlib.pyplot as plt
import numpy as np
from dmd import Dmd1d

# %%
dmd = Dmd1d(12, 15, 2, 5, 70)
print(len(dmd.mirror_pos_x))
print(len(dmd.mirror_pos_y))
plt.scatter(dmd.mirror_pos_x, dmd.mirror_pos_y, marker=".", s=3)
plt.axis("equal")
plt.show()
# Out:
# 350
# 350

# %%
np.linalg.norm(np.array([1, 1]))
# Out:
# 1.4142135623730951
